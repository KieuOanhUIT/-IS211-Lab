# %% [markdown]
# # MLP model

# %% [markdown]
# ## Cài đặt và nâng cấp các thư viện cần thiết

# %%
# Cài đặt TensorFlow Federated
# !pip install --upgrade tensorflow_federated

# Cài đặt TensorFlow và các thư viện cần thiết
# !pip install tensorflow tensorflow_datasets pandas scikit-learn
# Out:
# Requirement already satisfied: tensorflow_federated in /usr/local/lib/python3.11/dist-packages (0.87.0)
# Requirement already satisfied: absl-py==1.*,>=1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow_federated) (1.4.0)
# Requirement already satisfied: attrs~=23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow_federated) (23.1.0)
# Requirement already satisfied: cachetools~=5.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow_federated) (5.5.2)
# Requirement already satisfied: dm-tree==0.1.8 in /usr/local/lib/python3.11/dist-packages (from tensorflow_federated) (0.1.8)
# Requirement already satisfied: dp-accounting==0.4.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow_federated) (0.4.3)
# Requirement already satisfied: google-vizier==0.1.11 in /usr/local/lib/python3.11/dist-packages (from tensorflow_federated) (0.1.11)
# Requirement already satisfied: grpcio~=1.46 in /usr/local/lib/python3.11/dist-packages (from tensorflow_federated) (1.71.0)
# Requirement already satisfied: jaxlib==0.4.14 in /usr/local/lib/python3.11/dist-packages (from tensorflow_federated) (0.4.14)
# Requirement already satisfied: jax==0.4.14 in /usr/local/lib/python3.11/dist-packages (from tensorflow_federated) (0.4.14)
# Requirement already satisfied: ml-dtypes==0.2.*,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow_federated) (0.2.0)
# Requirement already satisfied: numpy~=1.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow_federated) (1.25.2)
# Requirement already satisfied: portpicker~=1.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow_federated) (1.6.0)
# Requirement already satisfied: scipy~=1.9.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow_federated) (1.9.3)
# Requirement already satisfied: tensorflow-model-optimization==0.7.5 in /usr/local/lib/python3.11/dist-packages (from tensorflow_federated) (0.7.5)
# Requirement already satisfied: tensorflow-privacy==0.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow_federated) (0.9.0)
# Requirement already satisfied: tensorflow==2.14.*,>=2.14.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow_federated) (2.14.1)
# Requirement already satisfied: tqdm~=4.64 in /usr/local/lib/python3.11/dist-packages (from tensorflow_federated) (4.67.1)
# Requirement already satisfied: typing-extensions==4.5.*,>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow_federated) (4.5.0)
# Requirement already satisfied: googleapis-common-protos==1.61.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow_federated) (1.61.0)
# Requirement already satisfied: mpmath~=1.2 in /usr/local/lib/python3.11/dist-packages (from dp-accounting==0.4.3->tensorflow_federated) (1.3.0)
# Requirement already satisfied: protobuf>=3.6 in /usr/local/lib/python3.11/dist-packages (from google-vizier==0.1.11->tensorflow_federated) (4.25.7)
# Requirement already satisfied: grpcio-tools>=1.35.0 in /usr/local/lib/python3.11/dist-packages (from google-vizier==0.1.11->tensorflow_federated) (1.62.3)
# Requirement already satisfied: sqlalchemy<=1.4.20,>=1.4 in /usr/local/lib/python3.11/dist-packages (from google-vizier==0.1.11->tensorflow_federated) (1.4.20)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.11/dist-packages (from jax==0.4.14->tensorflow_federated) (3.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.*,>=2.14.0->tensorflow_federated) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.*,>=2.14.0->tensorflow_federated) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.*,>=2.14.0->tensorflow_federated) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.*,>=2.14.0->tensorflow_federated) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.*,>=2.14.0->tensorflow_federated) (3.13.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.*,>=2.14.0->tensorflow_federated) (18.1.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.*,>=2.14.0->tensorflow_federated) (22.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.*,>=2.14.0->tensorflow_federated) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.*,>=2.14.0->tensorflow_federated) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.*,>=2.14.0->tensorflow_federated) (3.1.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.*,>=2.14.0->tensorflow_federated) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.*,>=2.14.0->tensorflow_federated) (0.37.1)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.*,>=2.14.0->tensorflow_federated) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.*,>=2.14.0->tensorflow_federated) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.*,>=2.14.0->tensorflow_federated) (2.14.0)
# Requirement already satisfied: scikit-learn==1.*,>=1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow-privacy==0.9.0->tensorflow_federated) (1.6.1)
# Requirement already satisfied: tensorflow-probability~=0.22.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow-privacy==0.9.0->tensorflow_federated) (0.22.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.*,>=1.0->tensorflow-privacy==0.9.0->tensorflow_federated) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.*,>=1.0->tensorflow-privacy==0.9.0->tensorflow_federated) (3.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from portpicker~=1.6->tensorflow_federated) (5.9.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow==2.14.*,>=2.14.0->tensorflow_federated) (0.45.1)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy<=1.4.20,>=1.4->google-vizier==0.1.11->tensorflow_federated) (3.2.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.*,>=2.14.0->tensorflow_federated) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.*,>=2.14.0->tensorflow_federated) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.*,>=2.14.0->tensorflow_federated) (3.8)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.*,>=2.14.0->tensorflow_federated) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.*,>=2.14.0->tensorflow_federated) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.*,>=2.14.0->tensorflow_federated) (3.1.3)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from tensorflow-probability~=0.22.0->tensorflow-privacy==0.9.0->tensorflow_federated) (4.4.2)
# Requirement already satisfied: cloudpickle>=1.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow-probability~=0.22.0->tensorflow-privacy==0.9.0->tensorflow_federated) (3.1.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14.*,>=2.14.0->tensorflow_federated) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14.*,>=2.14.0->tensorflow_federated) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow==2.14.*,>=2.14.0->tensorflow_federated) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow==2.14.*,>=2.14.0->tensorflow_federated) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow==2.14.*,>=2.14.0->tensorflow_federated) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow==2.14.*,>=2.14.0->tensorflow_federated) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow==2.14.*,>=2.14.0->tensorflow_federated) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow==2.14.*,>=2.14.0->tensorflow_federated) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14.*,>=2.14.0->tensorflow_federated) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow==2.14.*,>=2.14.0->tensorflow_federated) (3.2.2)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.14.1)
# Requirement already satisfied: tensorflow_datasets in /usr/local/lib/python3.11/dist-packages (4.9.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes==0.2.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (22.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.25.7)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: array_record>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow_datasets) (0.7.2)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.11/dist-packages (from tensorflow_datasets) (0.1.8)
# Requirement already satisfied: etils>=1.9.1 in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (1.12.2)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.11/dist-packages (from tensorflow_datasets) (4.2.1)
# Requirement already satisfied: promise in /usr/local/lib/python3.11/dist-packages (from tensorflow_datasets) (2.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from tensorflow_datasets) (5.9.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.11/dist-packages (from tensorflow_datasets) (18.1.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow_datasets) (2.32.3)
# Requirement already satisfied: simple_parsing in /usr/local/lib/python3.11/dist-packages (from tensorflow_datasets) (0.1.7)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.11/dist-packages (from tensorflow_datasets) (1.17.1)
# Requirement already satisfied: toml in /usr/local/lib/python3.11/dist-packages (from tensorflow_datasets) (0.10.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from tensorflow_datasets) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.9.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (0.8.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (2025.3.2)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->tensorflow_datasets) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->tensorflow_datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->tensorflow_datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->tensorflow_datasets) (2025.4.26)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.1.3)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /usr/local/lib/python3.11/dist-packages (from simple_parsing->tensorflow_datasets) (0.16)
# Requirement already satisfied: googleapis-common-protos<2,>=1.56.4 in /usr/local/lib/python3.11/dist-packages (from tensorflow-metadata->tensorflow_datasets) (1.61.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (2.0.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (3.2.2)

# %% [markdown]
# ## MLP - FedAvg

# %%
# Mô hình MLP sử dụng thuật toán Federated Learning - FedAvg
# Cài đặt thư viện cần thiết
import tensorflow as tf
import tensorflow_federated as tff
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, recall_score, precision_score, confusion_matrix
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Đọc dữ liệu
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/heart.csv', sep=';')

# Tách dữ liệu
X = df.drop('output', axis=1).values.astype(np.float32)
y = df['output'].values.astype(np.float32)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Tạo tf.data.Dataset cho client
def create_tf_dataset(features, labels):
    return tf.data.Dataset.from_tensor_slices((features, labels)).batch(16)

def create_keras_model():
    return tf.keras.Sequential([
        tf.keras.layers.Dense(32, activation='relu', input_shape=(X.shape[1],)),
        tf.keras.layers.Dense(16, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])

def create_federated_data(X, y, num_clients=5):
    client_data = []
    data_splits = np.array_split(np.column_stack((X, y)), num_clients)
    for split in data_splits:
        feats = split[:, :-1]
        labels = split[:, -1]
        client_data.append(create_tf_dataset(feats.astype(np.float32), labels.astype(np.float32)))
    return client_data

federated_train_data = create_federated_data(X_train, y_train, num_clients=5)
input_spec = federated_train_data[0].element_spec

# Khởi tạo mô hình
def model_fn():
    keras_model = create_keras_model()
    return tff.learning.models.from_keras_model(
        keras_model=keras_model,
        input_spec=input_spec,
        loss=tf.keras.losses.BinaryCrossentropy(),
        metrics=[tf.keras.metrics.BinaryAccuracy()]
    )


# Tạo trình tối ưu theo chuẩn mới của TFF
client_optimizer = tff.learning.optimizers.build_sgdm(learning_rate=0.01)
server_optimizer = tff.learning.optimizers.build_sgdm(learning_rate=1.0)

# Khởi tạo quá trình Federated Averaging (3.1. Lựa chọn thuật toán phù hợp FedAvg)
iterative_process = tff.learning.algorithms.build_weighted_fed_avg(
    model_fn=model_fn,
    client_optimizer_fn=client_optimizer,
    server_optimizer_fn=server_optimizer
)

state = iterative_process.initialize()

# Huấn luyện mô hình Federated Learning (3.3. Huấn luyện mô hình theo Federated learning)
for round_num in range(1, 51):
    result = iterative_process.next(state, federated_train_data)
    state = result.state
    print(f"Federated Round {round_num}: {result.metrics}")

# Lấy trọng số từ mô hình liên kết
final_model_weights = iterative_process.get_model_weights(state)

# Tạo lại mô hình keras và gán trọng số
fed_model = create_keras_model()
final_model_weights.assign_weights_to(fed_model)

# Dự đoán
y_pred_fed = (fed_model.predict(X_test) > 0.5).astype("int32").flatten()

# Đánh giá
print("\nĐánh giá mô hình học liên kết (FedAvg):")
print("Độ chính xác (Accuracy):", accuracy_score(y_test, y_pred_fed))
print("Độ nhạy (Recall - Positive):", recall_score(y_test, y_pred_fed))
print("Độ đặc hiệu (Specificity - Negative):", recall_score(y_test, y_pred_fed, pos_label=0))
print("Độ chính xác theo lớp (Precision):", precision_score(y_test, y_pred_fed))
print("Ma trận nhầm lẫn:\n", confusion_matrix(y_test, y_pred_fed))

# So sánh với mô hình học tập trung (Centralized Learning)
central_model = tf.keras.Sequential([
    tf.keras.layers.Dense(32, activation='relu', input_shape=(X.shape[1],)),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
central_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
central_model.fit(X_train, y_train, epochs=10, batch_size=16, verbose=0)

# Dự đoán và đánh giá mô hình (3.4. Đánh giá mô hình)
y_pred = (central_model.predict(X_test) > 0.5).astype("int32").flatten()

print("\nĐánh giá mô hình học tập trung:")
print("Độ chính xác (Accuracy):", accuracy_score(y_test, y_pred))
print("Độ nhạy (Recall - Positive):", recall_score(y_test, y_pred))
print("Độ đặc hiệu (Specificity - Negative):", recall_score(y_test, y_pred, pos_label=0))
print("Độ chính xác theo lớp (Precision):", precision_score(y_test, y_pred))
print("Ma trận nhầm lẫn:\n", confusion_matrix(y_test, y_pred))
# Out:
# ERROR:jax._src.xla_bridge:Jax plugin configuration error: Plugin module %s could not be loaded
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/jax/_src/xla_bridge.py", line 428, in discover_pjrt_plugins
#     plugin_module = importlib.import_module(plugin_module_name)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1147, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 690, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/jax_plugins/xla_cuda12/__init__.py", line 21, in <module>
#     from jax._src.lib import triton
# ImportError: cannot import name 'triton' from 'jax._src.lib' (/usr/local/lib/python3.11/dist-packages/jax/_src/lib/__init__.py)
# Mounted at /content/drive
# Federated Round 1: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.57024795), ('loss', 0.718468), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 2: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.5661157), ('loss', 0.709878), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 3: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.5785124), ('loss', 0.7017189), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 4: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.58677685), ('loss', 0.69398135), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 5: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.61157024), ('loss', 0.6866851), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 6: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.61157024), ('loss', 0.67980945), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 7: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.61570245), ('loss', 0.673231), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 8: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.6322314), ('loss', 0.6669247), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 9: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.6363636), ('loss', 0.6608475), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 10: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.6404959), ('loss', 0.6550371), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 11: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.6363636), ('loss', 0.6494119), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 12: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.6528926), ('loss', 0.64398104), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 13: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.677686), ('loss', 0.63872725), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 14: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.6735537), ('loss', 0.6335698), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 15: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.6859504), ('loss', 0.62852997), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 16: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.6859504), ('loss', 0.623617), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 17: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.6942149), ('loss', 0.61883336), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 18: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.6942149), ('loss', 0.6142359), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 19: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.7066116), ('loss', 0.6097474), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 20: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.7066116), ('loss', 0.6053739), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 21: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.7066116), ('loss', 0.60109466), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 22: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.71487606), ('loss', 0.596927), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 23: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.71900827), ('loss', 0.59286577), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 24: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.72727275), ('loss', 0.5889234), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 25: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.72727275), ('loss', 0.5850076), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 26: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.72727275), ('loss', 0.5811268), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 27: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.73966944), ('loss', 0.5773071), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 28: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.73966944), ('loss', 0.57354695), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 29: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.75206614), ('loss', 0.56982815), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 30: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.7644628), ('loss', 0.56613034), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 31: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.78099173), ('loss', 0.5625081), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 32: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.78512394), ('loss', 0.5589569), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 33: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.7892562), ('loss', 0.5554489), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 34: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.7933884), ('loss', 0.55199164), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 35: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.79752064), ('loss', 0.5484564), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 36: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8016529), ('loss', 0.54500556), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 37: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8016529), ('loss', 0.5415871), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 38: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8016529), ('loss', 0.5382139), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 39: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8057851), ('loss', 0.53486735), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 40: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8057851), ('loss', 0.53154975), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 41: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8140496), ('loss', 0.52829415), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 42: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.80991733), ('loss', 0.5250998), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 43: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8140496), ('loss', 0.52192575), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 44: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8181818), ('loss', 0.5187895), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 45: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8181818), ('loss', 0.51569706), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 46: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8181818), ('loss', 0.51264745), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 47: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8181818), ('loss', 0.50963295), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 48: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8181818), ('loss', 0.5066646), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 49: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8181818), ('loss', 0.5037429), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 50: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8181818), ('loss', 0.50085825), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# 2/2 [==============================] - 0s 9ms/step
#
# Đánh giá mô hình học liên kết (FedAvg):
# Độ chính xác (Accuracy): 0.8524590163934426
# Độ nhạy (Recall - Positive): 0.875
# Độ đặc hiệu (Specificity - Negative): 0.8275862068965517
# Độ chính xác theo lớp (Precision): 0.8484848484848485
# Ma trận nhầm lẫn:
#  [[24  5]
#  [ 4 28]]
# 2/2 [==============================] - 0s 15ms/step
#
# Đánh giá mô hình học tập trung:
# Độ chính xác (Accuracy): 0.8360655737704918
# Độ nhạy (Recall - Positive): 0.78125
# Độ đặc hiệu (Specificity - Negative): 0.896551724137931
# Độ chính xác theo lớp (Precision): 0.8928571428571429
# Ma trận nhầm lẫn:
#  [[26  3]
#  [ 7 25]]

# %%
# age	sex	cp	trtbps	chol	fbs	restecg	thalachh	exng	oldpeak	slp	caa	thall	output, dự đoán với dòng 200 -> 0
sample = np.array([[62,	1,	0,	120,	267,	0,	1,	99,	1,	1.8,	1,	2,	3]], dtype=np.float32)
sample_scaled = scaler.transform(sample)
fed_prediction = fed_model.predict(sample_scaled)
print(f"\nDự đoán bằng mô hình học liên kết - FedAvg")
print(f"Xác suất bị đau tim: {fed_prediction[0][0]:.4f}")
print("Kết luận:", "Nguy cơ cao" if fed_prediction[0][0] > 0.5 else "Nguy cơ thấp")

prediction = central_model.predict(sample_scaled)
print(f"\nDự đoán bằng mô hình học tập trung")
print(f"Xác suất bị đau tim: {prediction[0][0]:.4f}")
print("Kết luận:", "Nguy cơ cao" if prediction[0][0] > 0.5 else "Nguy cơ thấp")
# Out:
# 1/1 [==============================] - 0s 76ms/step
#
# Dự đoán bằng mô hình học liên kết - FedAvg
# Xác suất bị đau tim: 0.2168
# Kết luận: Nguy cơ thấp
# 1/1 [==============================] - 0s 52ms/step
#
# Dự đoán bằng mô hình học tập trung
# Xác suất bị đau tim: 0.0656
# Kết luận: Nguy cơ thấp

# %%
# age	sex	cp	trtbps	chol	fbs	restecg	thalachh	exng	oldpeak	slp	caa	thall	output, dự đoán với dòng 2 -> 1
sample = np.array([[63,	1,	3,	145,	233,	1,	0,	150,	0,	2.3,	0,	0, 1]], dtype=np.float32)
sample_scaled = scaler.transform(sample)
fed_prediction = fed_model.predict(sample_scaled)
print(f"\nDự đoán bằng mô hình học liên kết - FedAvg")
print(f"Xác suất bị đau tim: {fed_prediction[0][0]:.4f}")
print("Kết luận:", "Nguy cơ cao" if fed_prediction[0][0] > 0.5 else "Nguy cơ thấp")

prediction = central_model.predict(sample_scaled)
print(f"\nDự đoán bằng mô hình học tập trung")
print(f"Xác suất bị đau tim: {prediction[0][0]:.4f}")
print("Kết luận:", "Nguy cơ cao" if prediction[0][0] > 0.5 else "Nguy cơ thấp")
# Out:
# 1/1 [==============================] - 0s 59ms/step
#
# Dự đoán bằng mô hình học liên kết - FedAvg
# Xác suất bị đau tim: 0.8122
# Kết luận: Nguy cơ cao
# 1/1 [==============================] - 0s 154ms/step
#
# Dự đoán bằng mô hình học tập trung
# Xác suất bị đau tim: 0.6065
# Kết luận: Nguy cơ cao

# %% [markdown]
# ## MLP - FedProx

# %%
# Cài đặt thư viện
import tensorflow as tf
import tensorflow_federated as tff
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, recall_score, precision_score, confusion_matrix
from google.colab import drive

# Kết nối Google Drive
drive.mount('/content/drive')

# Đọc dữ liệu
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/heart.csv', sep=';')

# Tiền xử lý dữ liệu
X = df.drop('output', axis=1).values.astype(np.float32)
y = df['output'].values.astype(np.float32)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Chia dữ liệu cho client
def create_tf_dataset(features, labels):
    return tf.data.Dataset.from_tensor_slices((features, labels)).batch(16)

def create_keras_model():
    return tf.keras.Sequential([
        tf.keras.layers.Dense(32, activation='relu', input_shape=(X.shape[1],)),
        tf.keras.layers.Dense(16, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])

def create_federated_data(X, y, num_clients=5):
    client_data = []
    splits = np.array_split(np.column_stack((X, y)), num_clients)
    for split in splits:
        feats = split[:, :-1]
        labels = split[:, -1]
        client_data.append(create_tf_dataset(feats, labels))
    return client_data

federated_train_data = create_federated_data(X_train, y_train, num_clients=5)
input_spec = federated_train_data[0].element_spec

# Mô hình cho TFF
def model_fn():
    keras_model = create_keras_model()
    return tff.learning.models.from_keras_model(
        keras_model=keras_model,
        input_spec=input_spec,
        loss=tf.keras.losses.BinaryCrossentropy(),
        metrics=[tf.keras.metrics.BinaryAccuracy()]
    )

# Sử dụng FedProx (cần TFF >= 0.53+ để hỗ trợ build_weighted_fed_prox)
client_optimizer = tff.learning.optimizers.build_sgdm(learning_rate=0.01)
server_optimizer = tff.learning.optimizers.build_sgdm(learning_rate=1.0)

iterative_process = tff.learning.algorithms.build_weighted_fed_prox(
    model_fn=model_fn,
    client_optimizer_fn=client_optimizer,
    server_optimizer_fn=server_optimizer,
    proximal_strength=0.1  # Hệ số proximal lambda (tùy chỉnh theo thử nghiệm)
)

state = iterative_process.initialize()

# Huấn luyện mô hình Federated Learning với FedProx
for round_num in range(1, 51):
    result = iterative_process.next(state, federated_train_data)
    state = result.state
    print(f"Federated Round {round_num}: {result.metrics}")

# Trích xuất trọng số mô hình cuối cùng
final_model_weights = iterative_process.get_model_weights(state)

# Tạo lại mô hình keras để gán trọng số
fed_model = create_keras_model()
final_model_weights.assign_weights_to(fed_model)

# Đánh giá mô hình Federated
y_pred_fed = (fed_model.predict(X_test) > 0.5).astype("int32").flatten()

print("\nĐánh giá mô hình học liên kết (FedProx):")
print("Độ chính xác:", accuracy_score(y_test, y_pred_fed))
print("Độ nhạy (Recall - Positive):", recall_score(y_test, y_pred_fed))
print("Độ đặc hiệu (Recall - Negative):", recall_score(y_test, y_pred_fed, pos_label=0))
print("Precision:", precision_score(y_test, y_pred_fed))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_fed))

# So sánh với mô hình tập trung
central_model = tf.keras.Sequential([
    tf.keras.layers.Dense(32, activation='relu', input_shape=(X.shape[1],)),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
central_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
central_model.fit(X_train, y_train, epochs=10, batch_size=16, verbose=0)

y_pred = (central_model.predict(X_test) > 0.5).astype("int32").flatten()

print("\nĐánh giá mô hình học tập trung:")
print("Độ chính xác:", accuracy_score(y_test, y_pred))
print("Độ nhạy (Recall - Positive):", recall_score(y_test, y_pred))
print("Độ đặc hiệu (Recall - Negative):", recall_score(y_test, y_pred, pos_label=0))
print("Precision:", precision_score(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Federated Round 1: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.32231405), ('loss', 0.80855256), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 2: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.338843), ('loss', 0.7934198), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 3: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.36363637), ('loss', 0.77942246), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 4: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.38842976), ('loss', 0.7664181), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 5: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.4090909), ('loss', 0.75434405), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 6: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.42975205), ('loss', 0.7429578), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 7: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.45867768), ('loss', 0.73211867), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 8: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.47107437), ('loss', 0.72194934), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 9: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.48347107), ('loss', 0.7124566), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 10: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.5), ('loss', 0.7038414), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 11: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.53305787), ('loss', 0.69551337), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 12: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.5495868), ('loss', 0.6875086), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 13: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.5661157), ('loss', 0.6798342), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 14: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.5785124), ('loss', 0.6725015), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 15: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.59917355), ('loss', 0.6654617), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 16: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.61157024), ('loss', 0.65867615), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 17: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.62396693), ('loss', 0.65219796), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 18: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.6280992), ('loss', 0.64595675), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 19: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.6404959), ('loss', 0.6399769), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 20: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.6528926), ('loss', 0.6342002), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 21: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.677686), ('loss', 0.6284882), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 22: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.6942149), ('loss', 0.62288815), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 23: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.70247936), ('loss', 0.61744), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 24: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.70247936), ('loss', 0.612107), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 25: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.7107438), ('loss', 0.60692173), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 26: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.71900827), ('loss', 0.60185647), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 27: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.71900827), ('loss', 0.5968515), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 28: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.7231405), ('loss', 0.5919464), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 29: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.73966944), ('loss', 0.5872125), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 30: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.74380165), ('loss', 0.5825835), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 31: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.74793386), ('loss', 0.5780004), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 32: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.74793386), ('loss', 0.57349145), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 33: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.75206614), ('loss', 0.5690979), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 34: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.7644628), ('loss', 0.5648214), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 35: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.76859504), ('loss', 0.5606306), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 36: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.7768595), ('loss', 0.55653644), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 37: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.78099173), ('loss', 0.55250144), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 38: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.7892562), ('loss', 0.5485528), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 39: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.79752064), ('loss', 0.5446882), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 40: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.7933884), ('loss', 0.54096067), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 41: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.79752064), ('loss', 0.5372823), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 42: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.79752064), ('loss', 0.53363335), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 43: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.79752064), ('loss', 0.53002137), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 44: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.79752064), ('loss', 0.5264677), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 45: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8016529), ('loss', 0.5229867), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 46: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8057851), ('loss', 0.5195645), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 47: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.80991733), ('loss', 0.5161897), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 48: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8057851), ('loss', 0.5128606), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 49: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8057851), ('loss', 0.50961435), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 50: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8140496), ('loss', 0.5064349), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# 2/2 [==============================] - 0s 17ms/step
#
# Đánh giá mô hình học liên kết (FedProx):
# Độ chính xác: 0.819672131147541
# Độ nhạy (Recall - Positive): 0.8125
# Độ đặc hiệu (Recall - Negative): 0.8275862068965517
# Precision: 0.8387096774193549
# Confusion Matrix:
#  [[24  5]
#  [ 6 26]]
# 2/2 [==============================] - 0s 4ms/step
#
# Đánh giá mô hình học tập trung:
# Độ chính xác: 0.9016393442622951
# Độ nhạy (Recall - Positive): 0.90625
# Độ đặc hiệu (Recall - Negative): 0.896551724137931
# Precision: 0.90625
# Confusion Matrix:
#  [[26  3]
#  [ 3 29]]

# %%
# age	sex	cp	trtbps	chol	fbs	restecg	thalachh	exng	oldpeak	slp	caa	thall	output, dự đoán với dòng 200 -> 0
sample = np.array([[62,	1,	0,	120,	267,	0,	1,	99,	1,	1.8,	1,	2,	3]], dtype=np.float32)
sample_scaled = scaler.transform(sample)
fed_prediction = fed_model.predict(sample_scaled)
print(f"\nDự đoán bằng mô hình học liên kết - FedProx")
print(f"Xác suất bị đau tim: {fed_prediction[0][0]:.4f}")
print("Kết luận:", "Nguy cơ cao" if fed_prediction[0][0] > 0.5 else "Nguy cơ thấp")

prediction = central_model.predict(sample_scaled)
print(f"\nDự đoán bằng mô hình học tập trung")
print(f"Xác suất bị đau tim: {prediction[0][0]:.4f}")
print("Kết luận:", "Nguy cơ cao" if prediction[0][0] > 0.5 else "Nguy cơ thấp")
# Out:
# 1/1 [==============================] - 0s 21ms/step
#
# Dự đoán bằng mô hình học liên kết - FedProx
# Xác suất bị đau tim: 0.2771
# Kết luận: Nguy cơ thấp
# 1/1 [==============================] - 0s 20ms/step
#
# Dự đoán bằng mô hình học tập trung
# Xác suất bị đau tim: 0.0507
# Kết luận: Nguy cơ thấp

# %%
# age	sex	cp	trtbps	chol	fbs	restecg	thalachh	exng	oldpeak	slp	caa	thall	output, dự đoán với dòng 2 -> 1
sample = np.array([[63,	1,	3,	145,	233,	1,	0,	150,	0,	2.3,	0,	0, 1]], dtype=np.float32)
sample_scaled = scaler.transform(sample)
fed_prediction = fed_model.predict(sample_scaled)
print(f"\nDự đoán bằng mô hình học liên kết - FedProx")
print(f"Xác suất bị đau tim: {fed_prediction[0][0]:.4f}")
print("Kết luận:", "Nguy cơ cao" if fed_prediction[0][0] > 0.5 else "Nguy cơ thấp")

prediction = central_model.predict(sample_scaled)
print(f"\nDự đoán bằng mô hình học tập trung")
print(f"Xác suất bị đau tim: {prediction[0][0]:.4f}")
print("Kết luận:", "Nguy cơ cao" if prediction[0][0] > 0.5 else "Nguy cơ thấp")
# Out:
# 1/1 [==============================] - 0s 22ms/step
#
# Dự đoán bằng mô hình học liên kết - FedProx
# Xác suất bị đau tim: 0.6070
# Kết luận: Nguy cơ cao
# 1/1 [==============================] - 0s 20ms/step
#
# Dự đoán bằng mô hình học tập trung
# Xác suất bị đau tim: 0.7372
# Kết luận: Nguy cơ cao

# %% [markdown]
# # CNN Model

# %% [markdown]
# ## Cài đặt thư viện cần thiết

# %%
# !pip install --quiet tensorflow_federated nest-asyncio

# %% [markdown]
# ## CNN - FedAvg

# %%
# Mô hình CNN sử dụng thuật toán Federated Learning - FedAvg
import tensorflow as tf
import tensorflow_federated as tff
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, recall_score, precision_score, confusion_matrix
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Đọc dữ liệu
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/heart.csv', sep=';')

# Tiền xử lý dữ liệu
X = df.drop('output', axis=1).values.astype(np.float32)
y = df['output'].values.astype(np.float32)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_reshaped = X_scaled.reshape(-1, X.shape[1], 1, 1)  # CNN reshape
X_train, X_test, y_train, y_test = train_test_split(X_reshaped, y, test_size=0.2, random_state=42)

# Tạo tf.data.Dataset cho client
def create_tf_dataset(features, labels):
    return tf.data.Dataset.from_tensor_slices((features, labels)).shuffle(100).batch(16)

def create_keras_model():
    return tf.keras.Sequential([
        tf.keras.layers.Conv2D(16, (3, 1), activation='relu', input_shape=(X.shape[1], 1, 1)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])

def create_federated_data(X, y, num_clients=5):
    client_data = []
    data_splits = np.array_split(np.column_stack((X.reshape(len(X), -1), y)), num_clients)
    for split in data_splits:
        feats = split[:, :-1].reshape(-1, X.shape[1], 1, 1)
        labels = split[:, -1]
        client_data.append(create_tf_dataset(feats.astype(np.float32), labels.astype(np.float32)))
    return client_data

federated_train_data = create_federated_data(X_train, y_train, num_clients=5)
input_spec = federated_train_data[0].element_spec

# Khởi tạo mô hình
def model_fn():
    keras_model = create_keras_model()
    return tff.learning.models.from_keras_model(
        keras_model=keras_model,
        input_spec=input_spec,
        loss=tf.keras.losses.BinaryCrossentropy(),
        metrics=[tf.keras.metrics.BinaryAccuracy()]
    )

# Tạo trình tối ưu
client_optimizer = tff.learning.optimizers.build_sgdm(learning_rate=0.01)
server_optimizer = tff.learning.optimizers.build_sgdm(learning_rate=1.0)

# Khởi tạo FedAvg
iterative_process = tff.learning.algorithms.build_weighted_fed_avg(
    model_fn=model_fn,
    client_optimizer_fn=client_optimizer,
    server_optimizer_fn=server_optimizer
)

state = iterative_process.initialize()

# Huấn luyện mô hình
for round_num in range(1, 51):
    result = iterative_process.next(state, federated_train_data)
    state = result.state
    print(f"Federated Round {round_num}: {result.metrics}")

# Lấy trọng số mô hình
final_model_weights = iterative_process.get_model_weights(state)
fed_model = create_keras_model()
final_model_weights.assign_weights_to(fed_model)

# Dự đoán và đánh giá mô hình học liên kết
y_pred_fed = (fed_model.predict(X_test) > 0.5).astype("int32").flatten()

print("\nĐánh giá mô hình học liên kết (FedAvg - CNN):")
print("Độ chính xác (Accuracy):", accuracy_score(y_test, y_pred_fed))
print("Độ nhạy (Recall - Positive):", recall_score(y_test, y_pred_fed))
print("Độ đặc hiệu (Specificity - Negative):", recall_score(y_test, y_pred_fed, pos_label=0))
print("Độ chính xác theo lớp (Precision):", precision_score(y_test, y_pred_fed))
print("Ma trận nhầm lẫn:\n", confusion_matrix(y_test, y_pred_fed))

# Học tập trung để so sánh
central_model = create_keras_model()
central_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
central_model.fit(X_train, y_train, epochs=10, batch_size=16, verbose=0)

y_pred = (central_model.predict(X_test) > 0.5).astype("int32").flatten()

print("\nĐánh giá mô hình học tập trung (CNN):")
print("Độ chính xác (Accuracy):", accuracy_score(y_test, y_pred))
print("Độ nhạy (Recall - Positive):", recall_score(y_test, y_pred))
print("Độ đặc hiệu (Specificity - Negative):", recall_score(y_test, y_pred, pos_label=0))
print("Độ chính xác theo lớp (Precision):", precision_score(y_test, y_pred))
print("Ma trận nhầm lẫn:\n", confusion_matrix(y_test, y_pred))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Federated Round 1: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.661157), ('loss', 0.66797733), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 2: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.677686), ('loss', 0.6642922), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 3: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.6983471), ('loss', 0.6611493), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 4: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.6983471), ('loss', 0.6575995), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 5: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.6983471), ('loss', 0.6540429), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 6: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.6983471), ('loss', 0.6504428), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 7: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.7066116), ('loss', 0.6467907), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 8: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.71487606), ('loss', 0.64345217), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 9: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.7231405), ('loss', 0.64055), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 10: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.73966944), ('loss', 0.6373819), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 11: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.74380165), ('loss', 0.63474214), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 12: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.74793386), ('loss', 0.6312932), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 13: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.74380165), ('loss', 0.6291677), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 14: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.7644628), ('loss', 0.62614506), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 15: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.76859504), ('loss', 0.6236001), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 16: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.7768595), ('loss', 0.62017703), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 17: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.7768595), ('loss', 0.6172359), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 18: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.7768595), ('loss', 0.61393046), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 19: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.78512394), ('loss', 0.61098397), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 20: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.78512394), ('loss', 0.6078306), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 21: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.7892562), ('loss', 0.6049375), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 22: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8181818), ('loss', 0.6020541), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 23: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8181818), ('loss', 0.59872746), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 24: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8181818), ('loss', 0.59568965), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 25: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8140496), ('loss', 0.5922122), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 26: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8264463), ('loss', 0.5894011), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 27: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.822314), ('loss', 0.5867069), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 28: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8305785), ('loss', 0.5836953), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 29: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8305785), ('loss', 0.58023083), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 30: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8264463), ('loss', 0.57672524), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 31: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8305785), ('loss', 0.57379025), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 32: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8305785), ('loss', 0.570445), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 33: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8305785), ('loss', 0.56697714), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 34: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8264463), ('loss', 0.5638458), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 35: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8264463), ('loss', 0.560236), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 36: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.822314), ('loss', 0.55765027), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 37: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8347107), ('loss', 0.5549533), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 38: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8305785), ('loss', 0.55189794), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 39: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8264463), ('loss', 0.54841083), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 40: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8181818), ('loss', 0.54500234), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 41: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8181818), ('loss', 0.5418258), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 42: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.822314), ('loss', 0.5384177), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 43: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8181818), ('loss', 0.53501827), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 44: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8140496), ('loss', 0.53181094), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 45: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8140496), ('loss', 0.52885413), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 46: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8181818), ('loss', 0.52503246), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 47: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8181818), ('loss', 0.52152246), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 48: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8181818), ('loss', 0.5183912), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 49: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8181818), ('loss', 0.5150339), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 50: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.8181818), ('loss', 0.5116314), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# 2/2 [==============================] - 0s 5ms/step
#
# Đánh giá mô hình học liên kết (FedAvg - CNN):
# Độ chính xác (Accuracy): 0.8360655737704918
# Độ nhạy (Recall - Positive): 0.84375
# Độ đặc hiệu (Specificity - Negative): 0.8275862068965517
# Độ chính xác theo lớp (Precision): 0.84375
# Ma trận nhầm lẫn:
#  [[24  5]
#  [ 5 27]]
# 2/2 [==============================] - 0s 4ms/step
#
# Đánh giá mô hình học tập trung (CNN):
# Độ chính xác (Accuracy): 0.8852459016393442
# Độ nhạy (Recall - Positive): 0.875
# Độ đặc hiệu (Specificity - Negative): 0.896551724137931
# Độ chính xác theo lớp (Precision): 0.9032258064516129
# Ma trận nhầm lẫn:
#  [[26  3]
#  [ 4 28]]

# %%
# age	sex	cp	trtbps	chol	fbs	restecg	thalachh	exng	oldpeak	slp	caa	thall	output, dự đoán với dòng 200 -> 0
sample = np.array([[62,	1,	0,	120,	267,	0,	1,	99,	1,	1.8,	1,	2,	3]], dtype=np.float32)
sample_scaled_cnn = np.expand_dims(sample_scaled, axis=-1)      # (1, 13, 1)
sample_scaled_cnn = np.expand_dims(sample_scaled_cnn, axis=-1)  # (1, 13, 1, 1)

fed_prediction = fed_model.predict(sample_scaled_cnn)
print(f"\nDự đoán bằng mô hình học liên kết - FedAvg")
print(f"Xác suất bị đau tim: {fed_prediction[0][0]:.4f}")
print("Kết luận:", "Nguy cơ cao" if fed_prediction[0][0] > 0.5 else "Nguy cơ thấp")

prediction = central_model.predict(sample_scaled_cnn)
print(f"\nDự đoán bằng mô hình học tập trung")
print(f"Xác suất bị đau tim: {prediction[0][0]:.4f}")
print("Kết luận:", "Nguy cơ cao" if prediction[0][0] > 0.5 else "Nguy cơ thấp")
# Out:
# 1/1 [==============================] - 0s 20ms/step
#
# Dự đoán bằng mô hình học liên kết - FedAvg
# Xác suất bị đau tim: 0.4646
# Kết luận: Nguy cơ thấp
# 1/1 [==============================] - 0s 46ms/step
#
# Dự đoán bằng mô hình học tập trung
# Xác suất bị đau tim: 0.6535
# Kết luận: Nguy cơ cao

# %% [markdown]
# ## CNN - FedProx

# %%
# Cài đặt thư viện
import tensorflow as tf
import tensorflow_federated as tff
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, recall_score, precision_score, confusion_matrix
from google.colab import drive

# Kết nối Google Drive
drive.mount('/content/drive')

# Đọc dữ liệu
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/heart.csv', sep=';')

# Tiền xử lý dữ liệu
X = df.drop('output', axis=1).values.astype(np.float32)
y = df['output'].values.astype(np.float32)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Chia dữ liệu cho client
def create_tf_dataset(features, labels):
    return tf.data.Dataset.from_tensor_slices((features, labels)).batch(16)

# Cập nhật mô hình CNN
def create_keras_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Reshape((X.shape[1], 1), input_shape=(X.shape[1],)),  # Reshape dữ liệu thành dạng (samples, features, 1)
        tf.keras.layers.Conv1D(32, kernel_size=3, activation='relu'),  # Lớp convolutional 1D
        tf.keras.layers.MaxPooling1D(pool_size=2),  # Lớp max pooling
        tf.keras.layers.Conv1D(64, kernel_size=3, activation='relu'),  # Lớp convolutional thứ hai
        tf.keras.layers.MaxPooling1D(pool_size=2),  # Lớp max pooling thứ hai
        tf.keras.layers.Flatten(),  # Chuyển đổi đầu ra của các lớp convolutional thành dạng phẳng
        tf.keras.layers.Dense(64, activation='relu'),  # Lớp fully connected
        tf.keras.layers.Dense(32, activation='relu'),  # Lớp fully connected
        tf.keras.layers.Dense(1, activation='sigmoid')  # Lớp đầu ra cho bài toán phân loại nhị phân
    ])
    return model


def create_federated_data(X, y, num_clients=5):
    client_data = []
    splits = np.array_split(np.column_stack((X, y)), num_clients)
    for split in splits:
        feats = split[:, :-1]
        labels = split[:, -1]
        client_data.append(create_tf_dataset(feats, labels))
    return client_data

federated_train_data = create_federated_data(X_train, y_train, num_clients=5)
input_spec = federated_train_data[0].element_spec

# Mô hình cho TFF
def model_fn():
    keras_model = create_keras_model()
    return tff.learning.models.from_keras_model(
        keras_model=keras_model,
        input_spec=input_spec,
        loss=tf.keras.losses.BinaryCrossentropy(),
        metrics=[tf.keras.metrics.BinaryAccuracy()]
    )

# Sử dụng FedProx (cần TFF >= 0.53+ để hỗ trợ build_weighted_fed_prox)
client_optimizer = tff.learning.optimizers.build_sgdm(learning_rate=0.01)
server_optimizer = tff.learning.optimizers.build_sgdm(learning_rate=1.0)

iterative_process = tff.learning.algorithms.build_weighted_fed_prox(
    model_fn=model_fn,
    client_optimizer_fn=client_optimizer,
    server_optimizer_fn=server_optimizer,
    proximal_strength=0.1  # Hệ số proximal lambda (tùy chỉnh theo thử nghiệm)
)

state = iterative_process.initialize()

# Huấn luyện mô hình Federated Learning với FedProx
for round_num in range(1, 51):
    result = iterative_process.next(state, federated_train_data)
    state = result.state
    print(f"Federated Round {round_num}: {result.metrics}")

# Trích xuất trọng số mô hình cuối cùng
final_model_weights = iterative_process.get_model_weights(state)

# Tạo lại mô hình keras để gán trọng số
fed_model = create_keras_model()
final_model_weights.assign_weights_to(fed_model)

# Đánh giá mô hình Federated
y_pred_fed = (fed_model.predict(X_test) > 0.5).astype("int32").flatten()

print("\nĐánh giá mô hình học liên kết (FedProx):")
print("Độ chính xác:", accuracy_score(y_test, y_pred_fed))
print("Độ nhạy (Recall - Positive):", recall_score(y_test, y_pred_fed))
print("Độ đặc hiệu (Recall - Negative):", recall_score(y_test, y_pred_fed, pos_label=0))
print("Precision:", precision_score(y_test, y_pred_fed))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_fed))

# So sánh với mô hình tập trung
central_model = tf.keras.Sequential([
    tf.keras.layers.Dense(32, activation='relu', input_shape=(X.shape[1],)),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
central_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
central_model.fit(X_train, y_train, epochs=10, batch_size=16, verbose=0)

y_pred = (central_model.predict(X_test) > 0.5).astype("int32").flatten()

print("\nĐánh giá mô hình học tập trung:")
print("Độ chính xác:", accuracy_score(y_test, y_pred))
print("Độ nhạy (Recall - Positive):", recall_score(y_test, y_pred))
print("Độ đặc hiệu (Recall - Negative):", recall_score(y_test, y_pred, pos_label=0))
print("Precision:", precision_score(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Federated Round 1: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.446281), ('loss', 0.7018749), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 2: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.44214877), ('loss', 0.70098835), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 3: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.42561984), ('loss', 0.7001334), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 4: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.4338843), ('loss', 0.69934386), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 5: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.4214876), ('loss', 0.69859964), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 6: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.40082645), ('loss', 0.6978955), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 7: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.41322315), ('loss', 0.69722456), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 8: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.40495867), ('loss', 0.69658446), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 9: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.42975205), ('loss', 0.6959865), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 10: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.45454547), ('loss', 0.69542706), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 11: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.46280992), ('loss', 0.6949069), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 12: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.46694216), ('loss', 0.694412), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 13: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.4876033), ('loss', 0.69393694), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 14: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.5082645), ('loss', 0.6934749), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 15: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.5165289), ('loss', 0.69302607), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 16: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.5289256), ('loss', 0.69258267), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 17: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.5495868), ('loss', 0.6921503), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 18: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.55785125), ('loss', 0.6917253), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 19: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.5495868), ('loss', 0.6913009), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 20: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.5495868), ('loss', 0.69088984), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 21: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.553719), ('loss', 0.6905029), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 22: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.54545456), ('loss', 0.69013584), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 23: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.5495868), ('loss', 0.68978614), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 24: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.5495868), ('loss', 0.6894531), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 25: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.5495868), ('loss', 0.6891353), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 26: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.54545456), ('loss', 0.68883264), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 27: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.5495868), ('loss', 0.6885409), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 28: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.5413223), ('loss', 0.68825376), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 29: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.54545456), ('loss', 0.6879822), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 30: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.54545456), ('loss', 0.68770915), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 31: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.54545456), ('loss', 0.6874412), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 32: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.54545456), ('loss', 0.6871791), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 33: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.54545456), ('loss', 0.6869251), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 34: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.54545456), ('loss', 0.6866796), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 35: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.54545456), ('loss', 0.68643564), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 36: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.54545456), ('loss', 0.6861958), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 37: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.54545456), ('loss', 0.68596053), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 38: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.54545456), ('loss', 0.6857278), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 39: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.54545456), ('loss', 0.6854923), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 40: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.54545456), ('loss', 0.68524903), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 41: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.54545456), ('loss', 0.68501216), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 42: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.54545456), ('loss', 0.6847776), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 43: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.54545456), ('loss', 0.6845248), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 44: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.54545456), ('loss', 0.68426865), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 45: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.54545456), ('loss', 0.6840089), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 46: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.54545456), ('loss', 0.6837559), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 47: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.5495868), ('loss', 0.6835005), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 48: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.5495868), ('loss', 0.6832453), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 49: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.5495868), ('loss', 0.68298733), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# Federated Round 50: OrderedDict([('distributor', ()), ('client_work', OrderedDict([('train', OrderedDict([('binary_accuracy', 0.5495868), ('loss', 0.68273133), ('num_examples', 242), ('num_batches', 17)]))])), ('aggregator', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('finalizer', OrderedDict([('update_non_finite', 0)]))])
# 2/2 [==============================] - 0s 9ms/step
#
# Đánh giá mô hình học liên kết (FedProx):
# Độ chính xác: 0.5409836065573771
# Độ nhạy (Recall - Positive): 1.0
# Độ đặc hiệu (Recall - Negative): 0.034482758620689655
# Precision: 0.5333333333333333
# Confusion Matrix:
#  [[ 1 28]
#  [ 0 32]]
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7cdcd3574ea0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 6ms/step
#
# Đánh giá mô hình học tập trung:
# Độ chính xác: 0.8688524590163934
# Độ nhạy (Recall - Positive): 0.84375
# Độ đặc hiệu (Recall - Negative): 0.896551724137931
# Precision: 0.9
# Confusion Matrix:
#  [[26  3]
#  [ 5 27]]

# %%
# age	sex	cp	trtbps	chol	fbs	restecg	thalachh	exng	oldpeak	slp	caa	thall	output, dự đoán với dòng 2 -> 1
sample = np.array([[63,	1,	3,	145,	233,	1,	0,	150,	0,	2.3,	0,	0, 1]], dtype=np.float32)
sample_scaled = scaler.transform(sample)
fed_prediction = fed_model.predict(sample_scaled)
print(f"\nDự đoán bằng mô hình học liên kết - FedProx")
print(f"Xác suất bị đau tim: {fed_prediction[0][0]:.4f}")
print("Kết luận:", "Nguy cơ cao" if fed_prediction[0][0] > 0.5 else "Nguy cơ thấp")

prediction = central_model.predict(sample_scaled)
print(f"\nDự đoán bằng mô hình học tập trung")
print(f"Xác suất bị đau tim: {prediction[0][0]:.4f}")
print("Kết luận:", "Nguy cơ cao" if prediction[0][0] > 0.5 else "Nguy cơ thấp")
# Out:
# 1/1 [==============================] - 0s 31ms/step
#
# Dự đoán bằng mô hình học liên kết - FedProx
# Xác suất bị đau tim: 0.5539
# Kết luận: Nguy cơ cao
# 1/1 [==============================] - 0s 57ms/step
#
# Dự đoán bằng mô hình học tập trung
# Xác suất bị đau tim: 0.7004
# Kết luận: Nguy cơ cao
